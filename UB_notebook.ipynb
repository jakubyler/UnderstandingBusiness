# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 500)

# %%
df = pd.read_excel('ikano.xlsx')
df
# Out:
#             ID Gender  Income data MARITAL_STATUS EDUCATION CONTRACT_TYPE  \
# 0            1      M      90000.0        married      high     Full time
# 1            2      F       3400.0        married      high     Full time
# 2            3      F       3400.0        married      high     Full time
# 3            6      F       5000.0        married      high     Full time
# 4            7      M       4800.0        married      high     Full time
# ...        ...    ...          ...            ...       ...           ...
# 163005  163658      F       2500.0    not married      high     Full time
# 163006  163660      M       2500.0    not married    medium     Full time
# 163007  163662      F       2500.0    not married    medium     Part time
# 163008  163663      F       2500.0    not married    medium     Full time
# 163009  163664      F       3800.0        married      high     Full time
#
#                      PROFESSION           SECTOR Location of sales  Age  \
# ...

# %%
df.to_excel('ikano.xlsx')
